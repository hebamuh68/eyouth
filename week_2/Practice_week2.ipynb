# %% [markdown]
# <a href="https://colab.research.google.com/github/hebamuh68/eyouth/blob/main/week_2/Practice_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 2**

# %% [markdown]
# # **Part 1 – Math Operations**
#
# ![Background Image](https://raw.githubusercontent.com/hebamuh68/eyouth/main//week_2/math.png)

# %% [markdown]
# ## **1.1 Logical and Bitwise Operators**

# %% [markdown]
# ## **1.2 Assignment Operators**

# %% [markdown]
# ## **1.3 Comparison Operators**

# %% [markdown]
# ## **1.4 Membership Operators**

# %% [markdown]
# ---
# # **Part 2 – Strings**
#
# ![Background Image](https://raw.githubusercontent.com/hebamuh68/eyouth/main//week_2/string.png)

# %% [markdown]
# ## **2.1 Basic Operators**

# %%
animal=input("enter your fav animal")

print(f"i love the same {animal}")
# Out:
# enter your fav animalcat
# i love the same cat

# %% [markdown]
# ## **2.2 Properites Operators**

# %% [markdown]
# ## **2.3 Formatting Operators**

# %% [markdown]
# ## **2.4 Transformation Operators**

# %% [markdown]
# ---
#
#
# # **Part 3 – Conditionals (if / elif / else):**
#
# ![Background Image](https://raw.githubusercontent.com/hebamuh68/eyouth/main//week_2/if.png)

# %% [markdown]
# ## **3.1 Logical Operators**

# %% [markdown]
# ## **3.2 Nested if – if inside if**
#
# You can put an `if` statement **inside** another `if` statement!

# %% [markdown]
# <a href="https://colab.research.google.com/github/hebamuh68/eyouth/blob/main/week_1/Practice_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 — Python basics (Level 2)
#
# Run cells top to bottom (Shift+Enter). Short notes, lots of code.
#
# | Lessons covered | print, variables, syntax, types, `input`, arithmetic |
# |---|---|

# %% [markdown]
# ## 1 — Environment check

# %%
print("Python is ready.")
print("Version check:", __import__("sys").version.split()[0])

# %% [markdown]
# ## 2 — `print()` output

# %%
print("Hello")
print(42)
print("Year", 2026)
print("x", "y", "z", sep=" | ")
print("Hello", end=" ")
print("World")

# %%
title = "My first notebook"
lines = 10
print(title, "— lines of code so far:", lines)

# %% [markdown]
# ### Practice 1 — print three facts about you (change the strings)

# %%
# Your code: three print() lines (name, favourite subject, one hobby)

# %% [markdown]
# ## 3 — Variables and assignment

# %%
name = "Sara"
age = 15
height_m = 1.62
print(name, age, height_m)

# %%
score = 14
score = score + 1
score += 3
print(score)

# %%
a = 5
b = 9
temp = a
a = b
b = temp
print("a:", a, "b:", b)

# %% [markdown]
# ### Practice 2 — create `city`, `population_millions`, `visited` (bool), print them

# %% [markdown]
# ## 4 — Naming rules and comments

# %%
quiz_mark = 18
Quiz_mark = 12
print(quiz_mark, Quiz_mark)

# Python ignores full-line comments
total = quiz_mark + Quiz_mark  # inline comment
print("total", total)

# %% [markdown]
# ### Practice 3 — fix the invalid variable name on line 2 (run until it works)

# %%
correct_name = "OK"
# 2speed = 50   # invalid — uncomment and rewrite as valid

# %% [markdown]
# ## 5 — Arithmetic

# %%
print(7 + 3)
print(7 - 3)
print(7 * 3)
print(7 / 2)
print(7 // 2)
print(7 % 2)
print(2 ** 10)

# %%
price = 120
discount = 0.15
final = price * (1 - discount)
print("Final price:", final)

# %%
minutes = 135
hours = minutes // 60
mins_left = minutes % 60
print(hours, "h", mins_left, "min")

# %% [markdown]
# ### Practice 4 — average of three test scores (variables: t1, t2, t3)

# %%
t1 = 78
t2 = 85
t3 = 92
# average = ...
# print(average)

# %% [markdown]
# ### Practice 5 — percentage: `earned` points out of `total` (store as `pct`)

# %%
earned = 43
total = 50
# pct = ...
# print(pct)

# %% [markdown]
# ## 6 — Integers and floats

# %%
print(type(9))
print(type(9.0))
print(type(9 / 3))
print(type(9 // 3))
print(round(10 / 3, 2))

# %%
print(int(3.9))
print(float(7))
print(int("100") + 1)

# %% [markdown]
# ### Practice 6 — compute area of a rectangle `w` by `h` (float result)

# %%
w = 4.5
h = 6
# area = ...
# print(area)

# %% [markdown]
# ## 7 — Strings

# %%
s1 = "Hello"
s2 = 'World'
print(s1 + " " + s2)
print("na" * 4)
print(len("Python"))

# %%
word = "Programming"
print(word[0], word[-1])
print(word[0:4])
print(word[4:])

# %%
msg = "  hello world  "
print(msg.strip())
print(msg.strip().title())
print("ABC".lower())

# %%
name = "Mia"
score = 91
line = "Student: {} — score: {}".format(name, score)
print(line)
print(f"Student: {name} — score: {score}")

# %% [markdown]
# ### Practice 7 — build one f-string with variables `item` and `price`

# %%
item = "Notebook"
price = 12.5
# print(f"...")

# %% [markdown]
# ### Practice 8 — slice the word so it prints only the letters "code"

# %%
w = "decode"
# print(... slice ... )

# %% [markdown]
# ## 8 — Booleans and comparisons

# %%
print(10 > 5)
print(10 == 10)
print(3 != 3)
print(4 <= 4)
print(type(False))

# %%
age = 16
can_drive = age >= 18
print(can_drive)
print(True + False + True)

# %% [markdown]
# ### Practice 9 — set `passing` to True if `mark` is 50 or more

# %%
mark = 63
# passing = ...
# print(passing)

# %% [markdown]
# ## 9 — Indentation and `if` (preview)

# %%
temperature_c = 35
if temperature_c >= 30:
    print("Hot day")
    print("Drink water")
else:
    print("Cooler")

# %% [markdown]
# ### Practice 10 — add an `elif` branch for warm weather (20–29)

# %%
temperature_c = 24
if temperature_c >= 30:
    print("Hot day")
# add elif and else

# %% [markdown]
# ## 10 — `input()` (returns str)

# %%
# Simulated input for Colab without typing each run:
def fake_input(prompt, value):
    print(prompt + value)
    return value

a = fake_input("First number: ", "12")
b = fake_input("Second number: ", "8")
print("Sum as text concat:", a + b)
print("Sum as numbers:", int(a) + int(b))

# %%
# Live input — run in Colab; type when asked
# x = input("Enter your name: ")
# print("Hello", x)

print("Uncomment the two lines above to try real input().")

# %% [markdown]
# ### Practice 11 — read two floats (use input). Uncomment when ready.

# %%
# u = float(input("First: "))
# v = float(input("Second: "))
# print("Product:", u * v)

u, v = 2.5, 4
print("Demo product:", u * v)

# %% [markdown]
# ## 11 — Mini programs (put it together)

# %% [markdown]
# ### Practice 12 — BMI: `mass_kg` and `height_m` -> `bmi = mass / height ** 2`, print rounded

# %%
mass_kg = 55
height_m = 1.68
# bmi = ...
# print(round(bmi, 2))

# %% [markdown]
# ### Practice 13 — seconds to minutes and seconds

# %%
seconds = 175
# m = seconds // 60
# s = seconds % 60
# print(m, "min", s, "sec")

# %% [markdown]
# ### Practice 14 — cost with VAT: `base * (1 + vat_rate)`

# %%
base = 200
vat_rate = 0.14
# total = ...
# print(total)

# %% [markdown]
# ### Practice 15 — ticket price: children half price

# %%
full_price = 80
children = 2
adults = 2
# pay = adults * full_price + children * (full_price / 2)
# print(pay)

# %% [markdown]
# ## 12 — Extra drills

# %% [markdown]
# ### Practice 16 — predict then run

# %%
print("5" + "5")
print(int("5") + int("5"))
print(11 % 4)
print(2 ** 3 ** 2)

# %% [markdown]
# ### Practice 17 — fill conversions

# %%
s = "40"
# x = ... # x should be integer 40
# y = ... # y should be float 40.0
# print(x + 2, y / 5)

# %% [markdown]
# ### Practice 18 — split this string into two variables using slicing only

# %%
pair = "12:45"
# h = ...
# m = ...
# print(h, m)

# %% [markdown]
# ### Practice 19 — keyboard shortcut: set `ready` True if both tasks done

# %%
homework_done = True
project_done = False
# ready = ... use "and"
# print(ready)

# %% [markdown]
# ### Practice 20 — Celsius to Fahrenheit: F = C * 9/5 + 32

# %%
c = 22
# f = ...
# print(f)

# %% [markdown]
# ## Cheat sheet (run cell)

# %%
print("""
print(a, b)              output
x = value                assignment
+ - * / // % **          arithmetic
int() float() str()      conversion
input()                  returns str
f'{name}'                formatted string
type(x)                  inspect type
and or not               booleans
== != < > <= >=          comparisons
"""")
